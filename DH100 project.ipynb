# %% [markdown]
# ## Learning Pandas ##
# https://www.youtube.com/watch?v=vmEHCJofslg

# %% [markdown]
# ### Importing libraries ###

# %%
import os
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Loading data into Pandas ###

# %%
report1 = pd.read_csv('./kaggle - world happiness report/world-happiness-report.csv')
report2 = pd.read_csv('./kaggle - world happiness report/world-happiness-report-2021.csv')

# An alternative of reading the csv file into a dataframe
# happy_all = pd.read_csv('kaggle - world happiness report/world-happiness-report.csv')

# %% [markdown]
# ### Experimentation section ###

# %%
firstYear = report1['year'].min() #2005
lastYear = report1['year'].max() #2020

report_noYear = report1.drop(['year'], axis = 1)
report_noYear.groupby(['Country name']).mean()

report_2021.sort_values(['Country name'], ascending = True)
# Out:
#     Country name  year                  Regional indicator  Ladder score  \
# 148  Afghanistan  2021                          South Asia         2.523
# 92       Albania  2021          Central and Eastern Europe         5.117
# 108      Algeria  2021        Middle East and North Africa         4.887
# 56     Argentina  2021         Latin America and Caribbean         5.929
# 85       Armenia  2021  Commonwealth of Independent States         5.283
# ..           ...   ...                                 ...           ...
# 106    Venezuela  2021         Latin America and Caribbean         4.892
# 78       Vietnam  2021                      Southeast Asia         5.411
# 140        Yemen  2021        Middle East and North Africa         3.658
# 136       Zambia  2021                  Sub-Saharan Africa         4.073
# 147     Zimbabwe  2021                  Sub-Saharan Africa         3.145
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 148                           0.038         2.596         2.449
# 92                            0.059         5.234         5.001
# 108                           0.053         4.991         4.783
# 56                            0.056         6.040         5.819
# 85                            0.058         5.397         5.168
# ..                              ...           ...           ...
# 106                           0.064         5.017         4.767
# 78                            0.039         5.488         5.334
# 140                           0.070         3.794         3.521
# 136                           0.069         4.209         3.938
# 147                           0.058         3.259         3.030
#
#      Logged GDP per capita  Social support  Healthy life expectancy  ...  \
# 148                  7.695           0.463                   52.493  ...
# 92                   9.520           0.697                   68.999  ...
# 108                  9.342           0.802                   66.005  ...
# 56                   9.962           0.898                   69.000  ...
# 85                   9.487           0.799                   67.055  ...
# ..                     ...             ...                      ...  ...
# 106                  9.073           0.861                   66.700  ...
# 78                   8.973           0.850                   68.034  ...
# 140                  7.578           0.832                   57.122  ...
# 136                  8.145           0.708                   55.809  ...
# 147                  7.943           0.750                   56.201  ...
#
#      Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# 148      -0.102                      0.924                      2.43
# 92       -0.030                      0.901                      2.43
# 108      -0.067                      0.752                      2.43
# 56       -0.182                      0.834                      2.43
# 85       -0.168                      0.629                      2.43
# ..          ...                        ...                       ...
# 106      -0.169                      0.827                      2.43
# 78       -0.098                      0.796                      2.43
# 140      -0.147                      0.800                      2.43
# 136       0.061                      0.823                      2.43
# 147      -0.047                      0.821                      2.43
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 148                             0.370                         0.000
# 92                              1.008                         0.529
# 108                             0.946                         0.765
# 56                              1.162                         0.980
# 85                              0.996                         0.758
# ..                                ...                           ...
# 106                             0.852                         0.897
# 78                              0.817                         0.873
# 140                             0.329                         0.831
# 136                             0.528                         0.552
# 147                             0.457                         0.649
#
#      Explained by: Healthy life expectancy  \
# 148                                  0.126
# 92                                   0.646
# 108                                  0.552
# 56                                   0.646
# 85                                   0.585
# ..                                     ...
# 106                                  0.574
# 78                                   0.616
# 140                                  0.272
# 136                                  0.231
# 147                                  0.243
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 148                                       0.000                     0.122
# 92                                        0.491                     0.168
# 108                                       0.119                     0.144
# 56                                        0.544                     0.069
# 85                                        0.540                     0.079
# ..                                          ...                       ...
# 106                                       0.284                     0.078
# 78                                        0.679                     0.124
# 140                                       0.268                     0.092
# 136                                       0.487                     0.227
# 147                                       0.359                     0.157
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 148                                    0.010                1.895
# 92                                     0.024                2.250
# 108                                    0.120                2.242
# 56                                     0.067                2.461
# 85                                     0.198                2.127
# ..                                       ...                  ...
# 106                                    0.072                2.135
# 78                                     0.091                2.211
# 140                                    0.089                1.776
# 136                                    0.074                1.975
# 147                                    0.075                1.205
#
# [149 rows x 21 columns]

# %% [markdown]
# ### Renaming Columns ###

# %%
report1.rename(columns={'Life Ladder': 'Ladder score', 'Healthy life expectancy at birth': 'Healthy life expectancy'}, inplace=True)

# reference: https://stackoverflow.com/questions/11346283/renaming-columns-in-pandas

# %% [markdown]
# ### World Happiness Report 2021 with the year column ###

# %%
report2.insert(1,'year', 2021)
report2

#reference: https://stackoverflow.com/questions/18674064/how-do-i-insert-a-column-at-a-specific-column-index-in-pandas
# Out:
#     Country name  year  Regional indicator  Ladder score  \
# 0        Finland  2021      Western Europe         7.842
# 1        Denmark  2021      Western Europe         7.620
# 2    Switzerland  2021      Western Europe         7.571
# 3        Iceland  2021      Western Europe         7.554
# 4    Netherlands  2021      Western Europe         7.464
# ..           ...   ...                 ...           ...
# 144      Lesotho  2021  Sub-Saharan Africa         3.512
# 145     Botswana  2021  Sub-Saharan Africa         3.467
# 146       Rwanda  2021  Sub-Saharan Africa         3.415
# 147     Zimbabwe  2021  Sub-Saharan Africa         3.145
# 148  Afghanistan  2021          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# ..                              ...           ...           ...
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  ...  \
# 0                   10.775           0.954                   72.000  ...
# 1                   10.933           0.954                   72.700  ...
# 2                   11.117           0.942                   74.400  ...
# 3                   10.878           0.983                   73.000  ...
# 4                   10.932           0.942                   72.400  ...
# ..                     ...             ...                      ...  ...
# 144                  7.926           0.787                   48.700  ...
# 145                  9.782           0.784                   59.269  ...
# 146                  7.676           0.552                   61.400  ...
# 147                  7.943           0.750                   56.201  ...
# 148                  7.695           0.463                   52.493  ...
#
#      Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# 0        -0.098                      0.186                      2.43
# 1         0.030                      0.179                      2.43
# 2         0.025                      0.292                      2.43
# 3         0.160                      0.673                      2.43
# 4         0.175                      0.338                      2.43
# ..          ...                        ...                       ...
# 144      -0.131                      0.915                      2.43
# 145      -0.246                      0.801                      2.43
# 146       0.061                      0.167                      2.43
# 147      -0.047                      0.821                      2.43
# 148      -0.102                      0.924                      2.43
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 0                               1.446                         1.106
# 1                               1.502                         1.108
# 2                               1.566                         1.079
# 3                               1.482                         1.172
# 4                               1.501                         1.079
# ..                                ...                           ...
# 144                             0.451                         0.731
# 145                             1.099                         0.724
# 146                             0.364                         0.202
# 147                             0.457                         0.649
# 148                             0.370                         0.000
#
#      Explained by: Healthy life expectancy  \
# 0                                    0.741
# 1                                    0.763
# 2                                    0.816
# 3                                    0.772
# 4                                    0.753
# ..                                     ...
# 144                                  0.007
# 145                                  0.340
# 146                                  0.407
# 147                                  0.243
# 148                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# ..                                          ...                       ...
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                      0.481                3.253
# 1                                      0.485                2.868
# 2                                      0.413                2.839
# 3                                      0.170                2.967
# 4                                      0.384                2.798
# ..                                       ...                  ...
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895
#
# [149 rows x 21 columns]

# %% [markdown]
# ### World Happiness Report 2005 to 2020 with Regional indicator ###

# %%
country_region = report2[['Country name', 'Regional indicator']]
report1_region = report1.merge(country_region) #this takes out the missing country names from report_2021
report1_region
# Out:
#      Country name  year  Ladder score  Log GDP per capita  Social support  \
# 0     Afghanistan  2008         3.724               7.370           0.451
# 1     Afghanistan  2009         4.402               7.540           0.552
# 2     Afghanistan  2010         4.758               7.647           0.539
# 3     Afghanistan  2011         3.832               7.620           0.521
# 4     Afghanistan  2012         3.783               7.705           0.521
# ...           ...   ...           ...                 ...             ...
# 1881     Zimbabwe  2016         3.735               7.984           0.768
# 1882     Zimbabwe  2017         3.638               8.016           0.754
# 1883     Zimbabwe  2018         3.616               8.049           0.775
# 1884     Zimbabwe  2019         2.694               7.950           0.759
# 1885     Zimbabwe  2020         3.160               7.829           0.717
#
#       Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                       50.80                         0.718       0.168
# 1                       51.20                         0.679       0.190
# 2                       51.60                         0.600       0.121
# 3                       51.92                         0.496       0.162
# 4                       52.24                         0.531       0.236
# ...                       ...                           ...         ...
# 1881                    54.40                         0.733      -0.095
# 1882                    55.00                         0.753      -0.098
# 1883                    55.60                         0.763      -0.068
# 1884                    56.20                         0.632      -0.064
# 1885                    56.80                         0.643      -0.009
#
#       Perceptions of corruption  Positive affect  Negative affect  \
# 0                         0.882            0.518            0.258
# 1                         0.850            0.584            0.237
# 2                         0.707            0.618            0.275
# 3                         0.731            0.611            0.267
# 4                         0.776            0.710            0.268
# ...                         ...              ...              ...
# 1881                      0.724            0.738            0.209
# 1882                      0.751            0.806            0.224
# 1883                      0.844            0.710            0.212
# 1884                      0.831            0.716            0.235
# 1885                      0.789            0.703            0.346
#
#       Regional indicator
# 0             South Asia
# 1             South Asia
# 2             South Asia
# 3             South Asia
# 4             South Asia
# ...                  ...
# 1881  Sub-Saharan Africa
# 1882  Sub-Saharan Africa
# 1883  Sub-Saharan Africa
# 1884  Sub-Saharan Africa
# 1885  Sub-Saharan Africa
#
# [1886 rows x 12 columns]

# %% [markdown]
# ### Analysis of bottom cell ###
# It seems that there is a positive correlation between these two variables. <br>
# People have a longer life expectancy if they are happier in life.

# %%
ax = report1.plot.scatter(x = 'Healthy life expectancy', y = 'Ladder score', label = '2005 - 2020')
report2.plot.scatter(x = 'Healthy life expectancy', y = 'Ladder score', color = 'DarkGreen', ax = ax, label = '2021')
# source reference:
# https://stackoverflow.com/questions/13872533/plot-different-dataframes-in-the-same-figure
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#scatter-plot
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='Ladder score'>

# %% [markdown]
# ### Analysis of bottom cell ###
# The blue dots show the mean of the values throughout the years 2005 - 2020, while the green dots show only the year 2021. Through this data, it demonstrates that although 2021 had lower ladder scores than the mean of the 2005 to 2020 years, it also had the highest ladder scores as well as healthy life expectancy. According to the average, the happiness levels before the pandemic and after shows to be false.

# %%
report1_noYear = report1_region.drop(['year'], axis = 1)
report1_meanByCountry = report_noYear.groupby(['Country name']).mean()
ax = report1_meanByCountry.plot.scatter(x = 'Healthy life expectancy', y = 'Ladder score', label = '2005 - 2020')
report2.plot.scatter(x = 'Healthy life expectancy', y = 'Ladder score', color = 'DarkGreen', ax = ax, label = '2021')

report_noYear_mean.reset_index(inplace = True)

# %% [markdown]
# ### Analysis of bottom cell ###
# The blue vertical bar chart shows the data of 2005 to 2020 mean values of the ladder scores in increasing order corresponding to specific regions.
# <br>
# The green vertical bar chart shows the data of 2021 values of the ladder scores in increasing order corresponding to specific regions.
#
# #### Note: have to filter out the country names in the report from 2005 to 2020 that does not match 2021 data ####

# %%
# grouping by region for dataset 2005 - 2020
report1_meanByRegion = report_noYear.groupby(['Regional indicator']).mean()
report1_meanByRegion.reset_index(inplace = True)

#grouping by region for dataset 2021
report2_meanByRegion = report2.groupby(['Regional indicator']).mean()
report2_meanByRegion.reset_index(inplace = True)

# report1_meanByRegion.sort_values(['Ladder score'], ascending = True, inplace = True)
# report2_meanByRegion.sort_values(['Ladder score'], ascending = True, inplace = True)

sns.factorplot(x='Ladder score', y='Regional indicator', kind='bar', data=report1_meanByRegion)
sns.factorplot(x='Ladder score', y='Regional indicator', kind='bar', data=report2_meanByRegion)

# report1_meanByRegion[['Ladder score', 'Regional indicator']].plot.bar(color = 'DarkBlue', figsize=(15,5))
# report2_meanByRegion[['Ladder score', 'Regional indicator']].plot.bar(color = 'DarkGreen', figsize=(15,5))
# ax = report_no_2021.plot.scatter(x = 'Healthy life expectancy', y = 'Ladder score', label = '2005 - 2020')
# report_2021.plot.scatter(x = 'Healthy life expectancy', y = 'Ladder score', color = 'DarkGreen', ax = ax, label = '2021')
# Out:
# C:\Users\alici\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\alici\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### Analysis of bottom cell###
#
# [old] It is the overlap of the blue and green vertical bar, showing that the ladder score data in 2021 is higher than the mean between the years 2005 to 2020. Thus, showing that people were more satisfied with their lives in 2021 than the previous years.
#
# [new] Report 1 is data from 2005 to 2020 and report 2 is from 2021. This is a comparison between the two datasets of happiness levels by regional indicator. From the plot below, it shows that people were more satisfied with their lives in 2021 than previous years as report 2 demonstrates to be higher in most regions. The other regions are either lagging slightly behind or no major difference.
# <br><br>
# However, it is important to notice that the ladder score of this chart shows all regions are below the score 8. Meaning, happiness levels may have increased throughout the regions in 2021, but there is causing factors for it to be lower than 8.
# #### Note: have to filter out the country names in the report from 2005 to 2020 that does not match 2021 data ####

# %%
# ax = report2_meanByRegion[['Regional indicator', 'Ladder score']].plot.bar(color = 'DarkGreen', stacked = True)
# report1_meanByRegion[['Regional indicator', 'Ladder score']].plot.bar(color = 'DarkBlue', ax = ax, stacked = True)

r1_region_ladder = report1_meanByRegion[['Regional indicator', 'Ladder score']]
r2_region_ladder = report2_meanByRegion[['Regional indicator', 'Ladder score']]
r1_r2_meanByRegion = pd.concat([r1_region_ladder, r2_region_ladder])
r1_r2_meanByRegion['report'] = (len(r1_region_ladder)*(1,) + len(r2_region_ladder)*(2,))
r1_r2_meanByRegion.reset_index(inplace = True)
r1_r2_meanByRegion
sns.factorplot(x='Ladder score', y='Regional indicator', hue='report', kind='bar', data=r1_r2_meanByRegion)
#reference: https://stackoverflow.com/questions/42532319/grouped-bar-chart-from-two-pandas-data-frames
# Out:
# C:\Users\alici\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### Analysis of the bottom cell ###
# Compares the top ten percentile with the bottom ten percentile of the average of 2005 to 2020 and 2021 ladder score datasets.

# %%
# we can also just compare the report of 2020 vs 2021 to show the difference between the year prior to the outbreak of the pandemic

# compare the ranking of 2020 to 2021 <index sort by ladder score> -> see if there were changes

# use classification method model to predict next year's number 1 rank for happiness xxx doesn't correlate with research question

# compare the top 10 percentile and the bottom 10 percentile <- comparison of top and bottom countries of happiness
